# %% [markdown]
# # Lesson 1: Variables and Data Types

# %% [markdown]
# The website lessons followed in this lesson are:
#
# - [Lesson 1.1: Variables and Data Types](https://nasa-sarp.github.io/sarp_lessons/sarp_lessons/1_python_progression/1-general_python/1-1_variables_types_ifstatements.html)
#
# Additional practice problems for this section [can be found here](https://nasa-sarp.github.io/sarp_lessons/sarp_lessons/4_practice_problems/1_python/1-1_variables_data_practice.html).

# %% [markdown]
# ## Jupyter Notebooks
#
# Resources:
# * [Markdown tutorial](https://www.markdowntutorial.com/lesson/1/)
# * [Markdown reference](https://commonmark.org/help/)
# * [Jupyter shortcut keys](https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330)

# %%
# Making a new cell. Delete a cell. Change to markdown

# %% [markdown]
# ## 👩🏽‍💻 Communicating with the computer

# %%
# repeat a line of text back to you: "printing"
# modify it to change the output
print('Hello, world')
print("Boa tarde, mundo")  # single ' and double " are the same in Python

# %%
# you can also print numbers
print(3.1415927)

# %%
# you can print a couple of things together if you seperate them by commas
print('hi ', 8943)

# %%
# you can print the output of math calculations
print(4/8+5)

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# Write a cell of code to display the phrase: I am programming!
#
# :::

# %% [markdown]
# ## 👣 Assigning Variables

# %%
# Assigning the number 7 to a variable I named x
x = 7
# Assigning the number 2 to a variable I named y
y = 2

# %%
# assigning the text 'pineapple' to a variable I named my_lunch
my_lunch = 'pineapple'

# %%
print(x)
print('y is', y)

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# `print` the sum of your two variables x and y
#
# :::

# %% [markdown]
# ### 🌟 Key Clarification - Order of Execution
# One fundamental principle of code is that it executes things in a certain order - from top to bottom.

# %%
print('this will print first')
print('this will print second')

# %% [markdown]
# **Demo**: noting the difference using `sleep`

# %%
import time

# %%
print('this will print first')
time.sleep(3)  # Wait 3 seconds
print('this will print second')

# %%
today = 'Sunday'
print('print #1', today)
today = 'Thursday'
print('print #2', today)
today = 'Arbor Day'
print('print #3', today)

# %%
# Watch out when excuting cells out of order
today = 'Sunday'

# %%
today = 'Monday'

# %%
print(today)

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# What is the output of the following lines of code:
# ```
# x = 7
# x = 9
# y = x + 2
# print('y is ', y, ' and x is ', x)
# ```
# a) y is 9 and x is 7
#
# b) y is 11 and x is 9
#
# c) y is 9 and x is 9
#
# d) y is 11 and x is 7
#
# e) y is 7 and x is 9
# :::

# %% [markdown]
# ## Practice

# %% [markdown]
# ### Practice 1
#
# a) What is the output of the following code block?
#
# ```
# my_fav_icecream = 'mint'
# your_fav_icecream = 'blue moon'
# my_fav_icecream = 'peanut butter cup'
# print(my_fav_icecream)
# ```
#
# b) Create a new variable that holds the value of `chocolate` representing the flavor of the day

# %% [markdown]
# ### Practice 2
#
# Write a block of code that:
# 1. creates 3 variables, each containing values for sea surface temperature in celsius at three different port cities (Miami, 28 degrees. Havana, 30 degrees. Port-au-prince, 31 degrees)
# 2. takes the average value by adding the values together and dividing by 3
# 3. prints the average

# %% [markdown]
# ### Challenge Question 1
#
# Write a snippet of code that:
# 1. Defines a value of 6 to the radius value
# 2. Computes the area of a circle and assigns that to a value ($A = \pi*r^2$)
# 3. Displays the result

# %% [markdown]
# ### Challenge Question 2
#
# Google “Python operators”. Find a webpage with some operators and write a block of code that uses two of them below.
#
# If you are having a hard time finding a webpage you can use [this one](https://www.w3schools.com/python/python_operators.asp), which is the first page that shows up when I run the search.

# %% [markdown]
# ## 🧩 Data Types

# %%
# Example boolean
x = True
print(x)

# %%
# Capitalization matters

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# What are the data types of the following values?
# ```
# x = 9
# y = 'stratocumulus'
# z = False
# i = 3.0
# j = '2'
# k = "true"
# ```
# :::

# %% [markdown]
# Why do we care about data types?

# %%
x = 2
y = 3
a = 'cat'
b = 'fish'

# %% [markdown]
# ## 🔳 Booleans and Comparisons

# %% [markdown]
# Examples

# %%
# Example of "equal to" syntax
4+5 == 10

# %%
# Example: Checking if a state code is New York

# %%
# Python math (arithmetic operators)
(8+4+6)/3

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# Evaluate the output of the following:
# 1. `2*3 <= 6`
# 2. `8 == 8`
# 3. `6 != 3+3`
#
# a) True, True, False
#
# b) True, False, True
#
# c) False, True, False
#
# d) False, True, True
#
# e) True, True, True
#
# :::

# %% [markdown]
# ### Comparing Multiple Items

# %% [markdown]
# If you want to compare more than one thing there are two possible ways to do that, depending on what you want to happen. If you want to compare multiple items and see if they are both true, you use `and`.  If you want to compare multiple items and see if either of them are true, you use `or`.
#
# | Operator   | Use |
# |:---:|:---|
# | `and`  | checks if **both** logical statements are True |
# | `or`  | checks if **either** logical statements is True |

# %%
True and True

# %%
True and False

# %%
True or False

# %%
True or True

# %% [markdown]
# Examples

# %%
4 == 4 and 5 == 6
# True and False -> False

# %%
5 < 6 and 6 < 7
# True and True -> True

# %%
4 == 4 or 5 == 6
# True or False -> True

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# Evaluate the output of the following:
# 1. `5 <= 6 and 5 != 5`
# 2. `4 > 5 or 5 < 6`
#
# :::

# %% [markdown]
# 💡 Key Ideas
#
# * `and` and `or` are ways to compare multiple conditions at the same time.
# * When using `and` you are asking if **all** of the items are true.  When using `or` you are asking if any **one** of the items is true.

# %% [markdown]
# ## Practice

# %% [markdown]
# ### Practice 1
#
# Write a block of code that:
# 1. Create a variable to hold a value of 0.8 which represents the reflectances of light at 400 nm
# 2. Use a comparision to print whether or not the reflectances is greater than or equal to 0.5

# %% [markdown]
# ### Practice 2
#
# Fill in the comments in the block of code below to check for the following conditions:
# * `co2_above_400` indicates if the co2 value in houston was above 400 ppm
# * `greater_co2_houston` indicates is the observed co2 in houston was higher than the co2 observed in dallas
# * `is_2026` indicates if the year is 2026

# %%
co2_ppm_houston = 450
co2_ppm_dallas = 470
ch4_ppm = 1.8
year = 2026

co2_above_400 = # your code here
greater_co2_houston = # your code here
is_2026 = # your code here

# display the 3 variables defined above (bonus points for including a text string explaning the variable!)

# %% [markdown]
# ### Challenge Question 1
#
# Read a bit about if statements [here](https://openpython.org/articles/python-if-statements-explained-with-real-examples).
#
# Write an if statement which determines the salinity categoriation of the `salinity` variable and outputs the categorization to the user.
#
# | Salinity Category | Percent salt concentration |
# | --- | -- |
# | fresh water | less than 0.05% |
# | brackish | above 0.05% but below 3.0% |
# | saline | 3.0% or higher |
#
# _Note: there are at least two ways to solve this problem. One of them includes using a compound condition (a conditional that uses `and` / `or`) and another way which does not use the compound condition_

# %%
salinity = 3.1  # percentage (3.1%)

# your if statement
if # condition
    print('insert salinity category here')
# ...

# %% [markdown]
# ## Debugging: Error Messages
#
# Focus on: `TypeError`, `SyntaxError` and `NameError`

# %%
alt = 67
alt = 67 + 10
print(altitude)

# %%
prin(x)

# %%
x = 23
print:x)

# %%
x = 8
y = 'stratosphere'
z = 12
altitude = y + 1000
total_precipitation = x + z

# %% [markdown]
# ### Practice 1
#
# Fix the errors in the following snippets of code. Articulate:
# 1. What caused the error
# 2. How you will choose to fix it (there are multiple solutions)

# %%
x = 8
print('x")

# %%
flight1 = 'houston'
flight2 = 'dallas'
flight3 = 'galveston'
print(flight4)

# %%
x = 9
y = 'ten'
z = 11
print(x > y)

# %% [markdown]
# ### Practice 2
#
# Write two code blocks that error. (Bonus: get each of the two code blocks to return a different type of error)

# %% [markdown]
# ### Practice (Challenge)
#
# Diagnose the following error. What is causing the error? What is one way you might fix it?

# %%
a = 7
b = 9
c = a + b
d == b
print(d + 10)

# %% [markdown]
# ## Answers

# %% [markdown]
# ### Set 1

# %% [markdown]
# ### Practice 1
#
# a) What is the output of the following code block?
#
# ```
# my_fav_icecream = 'mint'
# your_fav_icecream = 'blue moon'
# my_fav_icecream = 'peanut butter cup'
# print(my_fav_icecream)
# ```
#
# b) Create a new variable that holds the value of `chocolate` representing the flavor of the day

# %%
# part A: output is "peanut butter cup"
my_fav_icecream = 'mint'
your_fav_icecream = 'blue moon'
my_fav_icecream = 'peanut butter cup'
print(my_fav_icecream)

# %%
# part B
my_fav_icecream = 'mint'
your_fav_icecream = 'blue moon'
my_fav_icecream = 'peanut butter cup'
print(my_fav_icecream)
flavor_of_the_day = 'chocolate'
print(flavor_of_the_day)

# %% [markdown]
# ### Practice 2
#
# Write a block of code that:
# 1. creates 3 variables, each containing values for sea surface temperature in celsius at three different port cities (Miami, 28 degrees. Havana, 30 degrees. Port-au-prince, 31 degrees)
# 2. takes the average value by adding the values together and dividing by 3
# 3. prints the average

# %%
miami_sst = 28
havana_sst = 30
portauprince_sst = 31

average_sst = (miami_sst + havana_sst + portauprince_sst) / 3

print(average_sst)

# %% [markdown]
# ### Challenge Question 1
#
# Write a snippet of code that:
# 1. Defines a value of 6 to the radius value
# 2. Computes the area of a circle and assigns that to a value ($A = \pi*r^2$)
# 3. Displays the result

# %%
radius = 6
area = 3.141 * radius**2
print(area)

# %% [markdown]
# ### Challenge Question 2
#
# Google “Python operators”. Find a webpage with some operators and write a block of code that uses two of them below.
#
# If you are having a hard time finding a webpage you can use [this one](https://www.w3schools.com/python/python_operators.asp), which is the first page that shows up when I run the search.

# %%
# floor division
10 // 3

# %%
# modulus operator
400 % 360

# %%
# exponent operator
8**3

# %% [markdown]
# ### Set 2

# %% [markdown]
# ### Practice 1
#
# Write a block of code that:
# 1. Create a variable to hold a value of 0.8 which represents the reflectance of light at 400 nm
# 2. Use a comparision to print whether or not the reflectance is greater than or equal to 0.5

# %%
reflectance = 0.8
print('reflectance is equal to or greater than 0.5:', reflectance >= 0.5)

# %% [markdown]
# ### Practice 2
#
# Fill in the comments in the block of code below to check for the following conditions:
# * `co2_above_400` indicates if the co2 value in houston was above 400 ppm
# * `greater_co2_houston` indicates is the observed co2 in houston was higher than the co2 observed in dallas
# * `is_2026` indicates if the year is 2026

# %%
co2_ppm_houston = 450
co2_ppm_dallas = 470
ch4_ppm = 1.8
year = 2026

co2_above_400 = co2_ppm_houston > 450
greater_co2_houston = co2_ppm_houston > co2_ppm_dallas
is_2026 = year == 2026

# display the 3 variables defined above (bonus points for including a text string explaning the variable!)
print('Is Houston CO2 above 400 ppm?', co2_above_400)
print('Is CO2 greater in Houston than Dallas?', greater_co2_houston)
print('Is the data year 2026?', is_2026)

# %% [markdown]
# ### Challenge Question 1
#
# Read a bit about if statements [here](https://openpython.org/articles/python-if-statements-explained-with-real-examples).
#
# Write an if statement which determines the salinity categoriation of the `salinity` variable and outputs the categorization to the user.
#
# | Salinity Category | Percent salt concentration |
# | --- | -- |
# | fresh water | less than 0.05% |
# | brackish | above 0.05% but below 3.0% |
# | saline | 3.0% or higher |
#
# _Note: there are at least two ways to solve this problem. One of them includes using a compound condition (a conditional that uses `and` / `or`) and another way which does not use the compound condition_

# %%
salinity = 3.1  # percentage (3.1%)

# your if statement
if salinity < 0.05:
    print('Water is fresh')
elif salinity < 3:
    print('Water is brackish')
else:
    print('Water is saline')

# %% [markdown]
# ### Set 3: Debugging

# %% [markdown]
# ### Practice 1
#
# Fix the errors in the following snippets of code. Articulate:
# 1. What caused the error
# 2. How you will choose to fix it (there are multiple solutions)
#
# _Note: There are multiple correct ways to fix each of the bugs below_

# %%
x = 8
print('x')

# %%
flight1 = 'houston'
flight2 = 'dallas'
flight3 = 'galveston'
flight4 = 'austin'
print(flight4)

# %%
x = 9
y = 'ten'
z = 11
print(x > z)

# %% [markdown]
# ### Practice (Challenge)
#
# Diagnose the following error. What is causing the error? What is one way you might fix it?

# %%
a = 7
b = 9
c = a + b
d = b
print(d + 10)
