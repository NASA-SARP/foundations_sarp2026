# %% [markdown]
# # lesson 4: xarray part 2 Opening Data

# %%
import numpy as np
import xarray as xr

# %% [markdown]
# ## Science Data!
#
# Dataset: [NASA MUR](https://podaac.jpl.nasa.gov/dataset/MUR25-JPL-L4-GLOB-v04.2)

# %% [markdown]
# One command to open a datasets is `xr.open_dataset()`, shown below.

# %%
import xarray as xr

# %%
mur_ds = xr.open_dataset(
    'data/20250503090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc'
)

# %%
# Note metadata
mur_ds
# Out:
# <xarray.Dataset> Size: 37MB
# Dimensions:           (time: 1, lat: 720, lon: 1440)
# Coordinates:
#   * time              (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat               (lat) float32 3kB -89.88 -89.62 -89.38 ... 89.62 89.88
#   * lon               (lon) float32 6kB -179.9 -179.6 -179.4 ... 179.6 179.9
# Data variables:
#     analysed_sst      (time, lat, lon) float64 8MB ...
#     analysis_error    (time, lat, lon) float64 8MB ...
#     mask              (time, lat, lon) float32 4MB ...
#     sea_ice_fraction  (time, lat, lon) float64 8MB ...
#     sst_anomaly       (time, lat, lon) float64 8MB ...
# Attributes: (12/54)
#     Conventions:                CF-1.7, ACDD-1.3
#     title:                      Daily 0.25-degree MUR SST, Interim near-real-...
#     summary:                    A low-resolution version of the MUR SST analy...
#     keywords:                   Oceans > Ocean Temperature > Sea Surface Temp...
# ...

# %%
mur_ds.attrs
# Out:
# {'Conventions': 'CF-1.7, ACDD-1.3',
#  'title': 'Daily 0.25-degree MUR SST, Interim near-real-time (nrt) product',
#  'summary': 'A low-resolution version of the MUR SST analysis, a merged, multi-sensor L4 Foundation SST analysis product from JPL.',
#  'keywords': 'Oceans > Ocean Temperature > Sea Surface Temperature',
#  'keywords_vocabulary': 'NASA Global Change Master Directory (GCMD) Science Keywords',
#  'standard_name_vocabulary': 'NetCDF Climate and Forecast (CF) Metadata Convention',
#  'history': 'near real time (nrt) version created at nominal 1-day latency.',
#  'source': 'MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G-NAVO, iQUAM-NOAA/NESDIS, Ice_Conc-OSISAF',
#  'platform': 'Terra, Aqua, GCOM-W, MetOp-B, Buoys/Ships',
#  'instrument': 'MODIS, AMSR2, AVHRR, in-situ',
#  'sensor': 'MODIS, AMSR2, AVHRR, in-situ',
#  'processing_level': 'L4',
#  'cdm_data_type': 'grid',
#  'product_version': '04.2nrt',
# ...

# %% [markdown]
# `````{admonition} Data Opening Checklist
# :class: tip
# 1. What variables or measurements are available in this dataset?
# 2. How is the dataset organized? What is the shape or size?
# 3. What spatial and/or temporal range does this dataset cover?
# 4. Do there appear to be any nodata values in this dataset?
# 5. Do the variables appear to have reasonable values?
# 6. Make the simplest plot possible of 1-2 variables. Does it match your expectations?
# `````

# %% [markdown]
# ### Inspecting the data

# %%
mur_ds.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 mur_ds.plot()
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/plot/accessor.py:921, in DatasetPlotAccessor.__call__(self, *args, **kwargs)
#     920 def __call__(self, *args, **kwargs) -> NoReturn:
# --> 921     raise ValueError(
#     922         "Dataset.plot cannot be called directly. Use "
#     923         "an explicit plot method, e.g. ds.plot.scatter(...)"
#     924     )
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)

# %%
mur_ds['analysed_sst']
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 720, lon: 1440)> Size: 8MB
# [1036800 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
mur_ds['analysed_sst'].plot()

# %% [markdown]
# What a lovely dataset! 🙂 🌊 🌡

# %% [markdown]
# ### Data Opening Check (Answers)

# %% [markdown]
# `````{admonition} Data Opening Checklist
# :class: tip
# 1. What variables or measurements are available in this dataset?
# 2. How is the dataset organized? What is the shape or size?
# 3. What spatial and/or temporal range does this dataset cover?
# 4. Do there appear to be any nodata values in this dataset?
# 5. Do the variables appear to have reasonable values?
# 6. Make the simplest plot possible of 1-2 variables. Does it match your expectations?
# `````

# %% [markdown]
# **#1: What variables or measurements are available in this dataset?**
#
# Let's look at the xarray output:

# %%
mur_ds
# Out:
# <xarray.Dataset> Size: 37MB
# Dimensions:           (time: 1, lat: 720, lon: 1440)
# Coordinates:
#   * time              (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat               (lat) float32 3kB -89.88 -89.62 -89.38 ... 89.62 89.88
#   * lon               (lon) float32 6kB -179.9 -179.6 -179.4 ... 179.6 179.9
# Data variables:
#     analysed_sst      (time, lat, lon) float64 8MB ...
#     analysis_error    (time, lat, lon) float64 8MB ...
#     mask              (time, lat, lon) float32 4MB ...
#     sea_ice_fraction  (time, lat, lon) float64 8MB ...
#     sst_anomaly       (time, lat, lon) float64 8MB ...
# Attributes: (12/54)
#     Conventions:                CF-1.7, ACDD-1.3
#     title:                      Daily 0.25-degree MUR SST, Interim near-real-...
#     summary:                    A low-resolution version of the MUR SST analy...
#     keywords:                   Oceans > Ocean Temperature > Sea Surface Temp...
# ...

# %% [markdown]
# Variables: analysed_sst, analysis_error, mask, sea_ice_fraction, sst_anomaly

# %% [markdown]
# **#2: How is the dataset organized? What is the shape or size?**
#
# 3 dimensions: time, latitude, longitude. There is 1 time value, 720 latitudes, and 1440 longitudes.

# %% [markdown]
# **#3: What spatial and/or temporal range does this dataset cover?**
#
# This data is from May 3rd, 2025. Geographically, it covers the whole world.

# %% [markdown]
# **#4: Do there appear to be any nodata values in this dataset?**
#
# One way to check for nodata values is to look at a plot of the data. Let's do that for just one band:

# %%
mur_ds.analysed_sst.plot()

# %% [markdown]
# The continents are areas of nodata. There does not appear to be nodata values in the ocean.

# %% [markdown]
# **#5: Do the variables appear to have reasonable values?**
#
# Let's check the minimum and maximum values for this dataset:

# %%
mur_ds.analysed_sst.min()
# Out:
# <xarray.DataArray 'analysed_sst' ()> Size: 8B
# array(271.35)
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
sst.analysed_sst.max()
# Out:
# <xarray.DataArray 'analysed_sst' ()> Size: 8B
# array(305.27)
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %% [markdown]
# **#6: Make the simplest plot possible of 1-2 variables. Does it match your expectations?**

# %%
mur_ds.analysed_sst.plot()

# %% [markdown]
# ### Subsetting
#
# _We do_
#
# Get data from: 5 to 65N, 85 to 36W

# %%
sst = mur_ds.analysed_sst

# %%
sst
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 720, lon: 1440)> Size: 8MB
# [1036800 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
sst['analysed_sst'].sel(lat=slice(5, 65), lon=slice(-85, -36))
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 240, lon: 196)> Size: 376kB
# [47040 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 960B 5.125 5.375 5.625 5.875 ... 64.38 64.62 64.88
#   * lon      (lon) float32 784B -84.88 -84.62 -84.38 ... -36.62 -36.38 -36.12
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
sst.sel(lat=slice(5, 65), lon=slice(-85, -36)).plot()

# %% [markdown]
# ## Some Computation

# %% [markdown]
# ### Arithmetic

# %%
sst_celsius = sst - 273

# %%
sst_celsius
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 720, lon: 1440)> Size: 8MB
# array([[[  nan,   nan,   nan, ...,   nan,   nan,   nan],
#         [  nan,   nan,   nan, ...,   nan,   nan,   nan],
#         [  nan,   nan,   nan, ...,   nan,   nan,   nan],
#         ...,
#         [-1.65, -1.65, -1.65, ..., -1.65, -1.65, -1.65],
#         [-1.65, -1.65, -1.65, ..., -1.65, -1.65, -1.65],
#         [-1.65, -1.65, -1.65, ..., -1.65, -1.65, -1.65]]])
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
# ...

# %% [markdown]
# ### Reading documentation
#
# To practice looking at documentation, let's look at [the docs page](https://docs.xarray.dev/en/stable/generated/xarray.DataArray.max.html) for the `xarray.DataArray.max()` method.
#
# We notice a few optional arguments - `dim` and `axis`. `dim` takes an integer as an argument and `axis` takes a string. Let's try them out.

# %%
sst.max()
# Out:
# <xarray.DataArray 'analysed_sst' ()> Size: 8B
# array(305.27)
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
sst.max(dim='lon').plot()

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# Run the snippet of code below to spatially subset the MUR SST to the Niño 3.4 region (5 degrees S - 5 degrees N and 120 - 170 W)
#
# **A)** Plot the region
#
# **B)** Write a line of code to answer the question: What is the average SST of this region?
#
# **C)** Write a line of code to answer the question: How does the average SST of this region change as we move from West to East? (i.e. What is the average SST across each longitude of this dataset?)
# :::

# %%
nino34 = sst.sel(lat=slice(-5, 5), lon=slice(120, 170))

nino34
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 40, lon: 200)> Size: 64kB
# [8000 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 160B -4.875 -4.625 -4.375 ... 4.375 4.625 4.875
#   * lon      (lon) float32 800B 120.1 120.4 120.6 120.9 ... 169.4 169.6 169.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
#     comment:                Interim near-real-time (nrt) version using Multi-...
#     source:                 MODIS_T-JPL, MODIS_A-JPL, AMSR2-REMSS, AVHRRMTB_G...

# %%
# Does this look correct?
nino34.plot()

# %% [markdown]
# ## Filtering or masking values

# %%
sst_celsius > 20
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 720, lon: 1440)> Size: 1MB
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]])
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
# ...

# %%
(sst_celsius > 20).plot()

# %%
sst_celsius.where(sst_celsius > 20)
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 720, lon: 1440)> Size: 8MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2025-05-03T09:00:00
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
# Attributes:
#     long_name:              analysed sea surface temperature
#     standard_name:          sea_surface_foundation_temperature
#     coverage_content_type:  physicalMeasurement
#     units:                  kelvin
#     valid_min:              -32767
#     valid_max:              32767
# ...

# %%
sst_celsius.where(sst_celsius > 20).plot()

# %% [markdown]
# ### Masking with values from another data array

# %%
(mur_ds.analysis_error > 0.4).plot()

# %%
(sst_celsius > 15) & (sst_celsius < 25)

# %% [markdown]
# :::{admonition} 📝 Check your understanding
# :class: tip
#
# Create a plot that shows where sst is above 10 degrees.
#
# :::

# %% [markdown]
# ## Practice

# %% [markdown]
# ### Practice 1
#
# **A)** Fill in the two comments in the block below to explain what is happening in each line of code
#
# **B)** Print `oisst_ds`. How many variables are present in the dataset?
#
# **C)** What is the product version of this dataset? What is the help email you could use to reach out to for suppoort? For the Anomaly variable specifically, what are the units and the long name for the dataarray?
#
# **D)** Subset the anomaly DataArray `oisst_anom` to 20-50 degrees North and 100-180 degrees East. Where in the world are we looking? Save this DataArray to a new variable.
#
# **E)** Create a new DataArray called `hot_water` that shows sst values where the water is hotter than the climatological average (i.e. where the sst anomaly value is greater than 0). Plot `hot_water`. Use the subset region you created in part C.
#
# **F)** What is the average number of degrees above the climatological average (anomaly sst) in this region on this date?

# %%
# Your comment here
oisst_ds = xr.open_dataset('data/oisst_sst_20220304.nc')
# Your comment here
oisst_anom = oisst_ds.anom
# Your comment here
oisst_anom.plot()

# %% [markdown]
# ## Practice Challenge
#
# Look at the documentation page for the xarray [`.rename()` method](https://docs.xarray.dev/en/stable/generated/xarray.DataArray.rename.html#xarray.DataArray.rename). Write a line of code that uses one dictionary argument to rename the `analysed_sst` data variable to `sst`.

# %% [markdown]
# # Answers

# %% [markdown]
# ### Practice 1
#
# **A)** Fill in the two comments in the block below to explain what is happening in each line of code
#
# **B)** Print `oisst_ds`. How many variables are present in the dataset?
#
# **C)** What is the product version of this dataset? What is the help email you could use to reach out to for suppoort? For the Anomaly variable specifically, what are the units and the long name for the dataarray?
#
# **D)** Subset the anomaly DataArray `oisst_anom` to 20-50 degrees North and 100-180 degrees East. Where in the world are we looking? Save this DataArray to a new variable.
#
# **E)** Create a new DataArray called `hot_water` that shows sst values where the water is hotter than the climatological average (i.e. where the sst anomaly value is greater than 0). Plot `hot_water`. Use the subset region you created in part C.
#
# **F)** What is the average number of degrees above the climatological average (anomaly sst) in this region on this date?

# %%
# Open the data file
oisst_ds = xr.open_dataset('data/oisst_sst_20220304.nc')
# Extract the sst anomaly variable
oisst_anom = oisst_ds.anom
# Plot sst anomaly
oisst_anom.plot()

# %% [markdown]
# **B)**
#
# There 4 variables: sst, anom, err, and ice.

# %%
oisst_ds
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:  (time: 1, zlev: 1, lat: 720, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 8B 2022-03-04T12:00:00
#   * zlev     (zlev) float32 4B 0.0
#   * lat      (lat) float32 3kB -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 6kB 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
# Data variables:
#     sst      (time, zlev, lat, lon) float32 4MB ...
#     anom     (time, zlev, lat, lon) float32 4MB nan nan nan nan ... 0.0 0.0 0.0
#     err      (time, zlev, lat, lon) float32 4MB ...
#     ice      (time, zlev, lat, lon) float32 4MB ...
# Attributes: (12/37)
#     Conventions:                CF-1.6, ACDD-1.3
#     title:                      NOAA/NCEI 1/4 Degree Daily Optimum Interpolat...
#     references:                 Reynolds, et al.(2007) Daily High-Resolution-...
#     source:                     ICOADS, NCEP_GTS, GSFC_ICE, NCEP_ICE, Pathfin...
# ...

# %% [markdown]
# **C)**

# %%
# Dataset attributes
print('product version', oisst_ds.attrs['product_version'])
print('product version', oisst_ds.attrs['creator_email'])
# Out:
# product version Version v02r01
# product version oisst-help@noaa.gov

# %%
# Anomaly dataarray attributes
print(oisst_ds.anom.attrs['units'])
print(oisst_ds.anom.attrs['long_name'])
# Out:
# Celsius
# Daily sea surface temperature anomalies

# %% [markdown]
# **D)**

# %%
west_pacific = oisst_anom.sel(lat=slice(20, 50), lon=slice(100, 180))
west_pacific.plot()

# %% [markdown]
# **E)**

# %%
hot_water = west_pacific.where(oisst_anom > 0)
hot_water.plot()

# %% [markdown]
# **F)**
#
# The mean anomaly of this region is 0.88 degrees Celsius

# %%
hot_water.mean()
# Out:
# <xarray.DataArray 'anom' ()> Size: 4B
# array(0.88470054, dtype=float32)
# Attributes:
#     long_name:  Daily sea surface temperature anomalies
#     units:      Celsius
#     valid_min:  -1200
#     valid_max:  1200

# %%
# Open the file as a dataset
oisst_ds = xr.open_dataset('data/oisst_sst_20220304.nc')
# Extract the SST anomaly variable
oisst_anom = oisst_ds.anom
# Plot the SST anomaly
oisst_anom.plot()

# %% [markdown]
# **B)**

# %%
west_pacific = oisst_anom.sel(lat=slice(20, 50), lon=slice(100, 180))
west_pacific.plot()

# %%
hot_water = west_pacific.where(oisst_anom > 0)
hot_water.plot()

# %%
hot_water.mean()
# Out:
# <xarray.DataArray 'anom' ()> Size: 4B
# array(0.88470054, dtype=float32)
# Attributes:
#     long_name:  Daily sea surface temperature anomalies
#     units:      Celsius
#     valid_min:  -1200
#     valid_max:  1200
